# %%
from PIL import Image
import os

def convert_to_webp(input_path, output_path):
    image = Image.open(input_path)
    image.save(output_path, "WEBP", lossless=True)
    print(f"Converted {input_path} → {output_path}")

# Example usage
input_image = "abc.jpeg"  # Change to your file name
output_image = "image.webp"

convert_to_webp(input_image, output_image)
# Out:
# Converted weed.jpg → image.webp

# %%
from PIL import Image
import os
import requests
from io import BytesIO

# # List of image URLs
# image_urls = []  # Replace with your actual image URLs

# Create output directory if it doesn't exist
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

def download_and_convert_to_webp(image_url, output_path):
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()
        image = Image.open(BytesIO(response.content))
        image.save(output_path, "WEBP", lossless=True)
        print(f"Converted {image_url} → {output_path}")
    except Exception as e:
        print(f"Error converting {image_url}: {e}")

# Process each image in the list
for image_url in image_urls:
    filename = os.path.basename(image_url).split('.')[0] + ".webp"
    output_path = os.path.join(output_dir, filename)
    download_and_convert_to_webp(image_url, output_path)
# Out:
# Converted https://codesminds.com/wp-content/uploads/2024/12/weed-1.jpg → output\weed-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/bioped-1.jpg → output\bioped-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/hannon-1.jpg → output\hannon-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/monster8-1.jpg → output\monster8-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/by-kumni-1.jpg → output\by-kumni-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/dental-1.jpg → output\dental-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/hamdme-the-bag-1.jpg → output\hamdme-the-bag-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/networkelite-1.jpg → output\networkelite-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/cafe.jpg → output\cafe.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/eye.jpg → output\eye.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/islamic.jpg → output\islamic.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/dental-1-1.jpg → output\dental-1-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/chatbot.jpg → output\chatbot.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/ecom.jpg → output\ecom.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/islamic-1.jpg → output\islamic-1.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/job.jpg → output\job.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/Health-foundation-we.jpg → output\Health-foundation-we.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/e-tasbih.jpg → output\e-tasbih.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/track.jpg → output\track.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/react-app.jpg → output\react-app.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/extr.jpg → output\extr.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/ex-app.jpg → output\ex-app.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/app.jpg → output\app.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/app2.jpg → output\app2.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/app3.jpg → output\app3.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/app4.jpg → output\app4.webp
# Converted https://codesminds.com/wp-content/uploads/2024/12/covid.jpg → output\covid.webp

# %%
from PIL import Image
import os
import requests
from io import BytesIO

# # List of image URLs
# image_urls = [
#     "from PIL import Image
import os
import requests
from io import BytesIO

# List of image URLs
image_urls = []
# Create output directory if it doesn't exist
output_dir = "banner"
os.makedirs(output_dir, exist_ok=True)

def download_and_convert_to_webp(image_url, output_path):
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()
        image = Image.open(BytesIO(response.content))
        image.save(output_path, "WEBP", lossless=True)
        print(f"Converted {image_url} → {output_path}")
    except Exception as e:
        print(f"Error converting {image_url}: {e}")

# Process each image in the list
for image_url in image_urls:
    filename = os.path.basename(image_url).split('.')[0] + ".webp"
    output_path = os.path.join(output_dir, filename)
    download_and_convert_to_webp(image_url, output_path)

# Create output directory if it doesn't exist
output_dir = "banner_images"
os.makedirs(output_dir, exist_ok=True)

def download_and_convert_to_webp(image_url, output_path):
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()
        image = Image.open(BytesIO(response.content))
        image.save(output_path, "WEBP", lossless=True)
        print(f"Converted {image_url} → {output_path}")
    except Exception as e:
        print(f"Error converting {image_url}: {e}")

# Process each image in the list
for image_url in image_urls:
    filename = os.path.basename(image_url).split('.')[0] + ".webp"
    output_path = os.path.join(output_dir, filename)
    download_and_convert_to_webp(image_url, output_path)
# Out:
# Converted https://codesminds.com/wp-content/uploads/2024/10/womans-hands-typing-on-keyboard-at-desk-working-in-JDKKPMP.jpg → banner\womans-hands-typing-on-keyboard-at-desk-working-in-JDKKPMP.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/freelance-creative-747KTXU.jpg → banner\freelance-creative-747KTXU.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/searching-for-solutions-group-of-three-young-and-p-QKN7X76.jpg → banner\searching-for-solutions-group-of-three-young-and-p-QKN7X76.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/technologies-making-business-easier-4BJ2BZZ.jpg → banner\technologies-making-business-easier-4BJ2BZZ.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/technologies-making-business-easier-4BJ2BZZ.jpg → banner\technologies-making-business-easier-4BJ2BZZ.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/womans-hands-typing-on-keyboard-at-desk-working-in-JDKKPMP.jpg → banner_images\womans-hands-typing-on-keyboard-at-desk-working-in-JDKKPMP.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/freelance-creative-747KTXU.jpg → banner_images\freelance-creative-747KTXU.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/searching-for-solutions-group-of-three-young-and-p-QKN7X76.jpg → banner_images\searching-for-solutions-group-of-three-young-and-p-QKN7X76.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/technologies-making-business-easier-4BJ2BZZ.jpg → banner_images\technologies-making-business-easier-4BJ2BZZ.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10/technologies-making-business-easier-4BJ2BZZ.jpg → banner_images\technologies-making-business-easier-4BJ2BZZ.webp

# %%
from PIL import Image
import os
import requests
from io import BytesIO

# # List of image URLs
# image_urls = [
#     "from PIL import Image
import os
import requests
from io import BytesIO

# List of image URLs
image_urls = []

# Create output directory if it doesn't exist
output_dir = "crousal_images"
os.makedirs(output_dir, exist_ok=True)

def download_and_convert_to_webp(image_url, output_path):
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()
        image = Image.open(BytesIO(response.content))
        image.save(output_path, "WEBP", lossless=True)
        print(f"Converted {image_url} → {output_path}")
    except Exception as e:
        print(f"Error converting {image_url}: {e}")

# Process each image in the list
for image_url in image_urls:
    filename = os.path.basename(image_url).split('.')[0] + ".webp"
    output_path = os.path.join(output_dir, filename)
    download_and_convert_to_webp(image_url, output_path)


# Create output directory if it doesn't exist
output_dir = "crousal_images"
os.makedirs(output_dir, exist_ok=True)

def download_and_convert_to_webp(image_url, output_path):
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()
        image = Image.open(BytesIO(response.content))
        image.save(output_path, "WEBP", lossless=True)
        print(f"Converted {image_url} → {output_path}")
    except Exception as e:
        print(f"Error converting {image_url}: {e}")

# Process each image in the list
for image_url in image_urls:
    filename = os.path.basename(image_url).split('.')[0] + ".webp"
    output_path = os.path.join(output_dir, filename)
    download_and_convert_to_webp(image_url, output_path)
# Out:
# Converted https://codesminds.com/wp-content/uploads/2024/10/womans-hands-typing-on-keyboard-at-desk-working-in-JDKKPMP.jpg → crousal_images\womans-hands-typing-on-keyboard-at-desk-working-in-JDKKPMP.webp
# Converted https://codesminds.com/wp-content/uploads/2024/10